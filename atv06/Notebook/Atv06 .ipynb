// %% [markdown]
// # Atv06

// %% [markdown]
// Dados os valores de um depósito fixo mensal e um montante desejado, crie uma classe para determinar quantos meses serão necessários para acumular o montante desejado, considerando juros mensais de 0,5%.

// %%
import java.util.Scanner;




        float meta, deposito, acumulado,juros = 0.5f ;
        int meses=1;
        /* */       
        System.out.println ("Digite o monto que você quer acumular");
        Scanner ac = new Scanner(System.in);
        meta = ac.nextFloat();
        System.out.println ("quer acumular:" + meta);

        System.out.println ("Digite o monto que você quer depositar fixo Mensual ");
        Scanner dpScanner = new Scanner(System.in);
        deposito = dpScanner.nextFloat();
        System.out.println ("quer depositar fixo mensual: " + deposito);
        acumulado=0;

        System.out.println ("Lembrando que a taxa de juro mensual ê: " + juros);
        
        if (meta>deposito){
          while (meta>acumulado) {
            acumulado = acumulado*1.05f+deposito;
            
            
            System.out.println("o mes nro " + meses + " leva acumulado: " + acumulado + "reais ");
              meses++;
            
          }
          System.out.println ("Fim Voce demorou:" + (meses-1) + " meses," + " su meta era: " + meta + " e acumulo: " + acumulado);
        } else {
          System.out.println("Voce ja tem o valor desejado Sõ com o primer deposito.");
        }
// Out:
// Digite o monto que você quer acumular
// 5000
// quer acumular:5000.0
// Digite o monto que você quer depositar fixo Mensual
// 550
// quer depositar fixo mensual: 550.0
// Lembrando que a taxa de juro mensual ê: 0.5
// o mes nro 1 leva acumulado: 550.0reais
// o mes nro 2 leva acumulado: 1127.5reais
// o mes nro 3 leva acumulado: 1733.875reais
// o mes nro 4 leva acumulado: 2370.5688reais
// o mes nro 5 leva acumulado: 3039.0972reais
// o mes nro 6 leva acumulado: 3741.052reais
// o mes nro 7 leva acumulado: 4478.1045reais
// o mes nro 8 leva acumulado: 5252.0093reais
// Fim Voce demorou:8 meses, su meta era: 5000.0 e acumulo: 5252.0093
// null
