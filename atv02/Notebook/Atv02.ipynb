// %% [markdown]
// # Atv02

// %% [markdown]
// Exibir a mensagem “Informe um inteiro: “, deixando o cursor na mesma linha

// %%
System.out.println("Informe um inteiro a");
// Out:
// Informe um inteiro a
// null

// %% [markdown]
// Atribuir o produto das variáveis b e c para a variável a

// %%
int a,b=2,c=3;
        
a = b*c;
// Out:
// null

// %% [markdown]
// Demonstrar a execução do cálculo e utilizar um comentário para afirmar que é um programa de exemplo de folha de pagamento.

// %%
int a,b=2,c=3;   
a = b*c;
System.out.println("resultado do produto b * c= " + a + " atribuido a");
// Out:
// resultado do produto b * c= 6 atribuido a
// null

// %%
System.out.println("Ê um exemplo que pode ser utilizado para uma folha de pagamento");
// Out:
// Ê um exemplo que pode ser utilizado para uma folha de pagamento
// null
